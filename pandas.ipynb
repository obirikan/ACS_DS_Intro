# %%
import pandas as pd

# %%
# read csv file 
df=pd.read_csv("dataset.csv")

df.head()
# Out:
#    order_date customer_id product_category  order_amount  discount_percent  \
# 0  2023-03-22   CUST_0087      electronics     72.230845              25.0
# 1  2023-11-09   CUST_0140      ELECTRONICS    247.985448              25.0
# 2  2024-01-20   CUST_0007           Sports    242.611682               NaN
# 3  2023-06-08   CUST_0030    Home & Garden   1800.303058               NaN
# 4  2023-03-04   CUST_0014      Electronics    236.575855               NaN
#
#    discount_amount  final_price  quantity  shipping_days delivery_date  \
# 0        18.057711    54.173134         8       3.964745    2023-03-25
# 1        61.996362   185.989086         3       4.314526           NaN
# 2         0.000000   242.611682         7       4.717731    2024-01-24
# 3         0.000000  1800.303058         9       7.652650    2023-06-15
# 4         0.000000   236.575855         2       5.659466    2023-03-09
#
#   order_status refund_status  customer_rating payment_method
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 203 entries, 0 to 202
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   order_date        203 non-null    object
#  1   customer_id       203 non-null    object
#  2   product_category  203 non-null    object
#  3   order_amount      203 non-null    float64
#  4   discount_percent  142 non-null    float64
#  5   discount_amount   203 non-null    float64
#  6   final_price       203 non-null    float64
#  7   quantity          203 non-null    int64
#  8   shipping_days     191 non-null    float64
#  9   delivery_date     152 non-null    object
#  10  order_status      203 non-null    object
#  11  refund_status     191 non-null    object
#  12  customer_rating   176 non-null    float64
#  13  payment_method    203 non-null    object
# dtypes: float64(6), int64(1), object(7)
# memory usage: 22.3+ KB

# %%
df.describe()
# Out:
#        order_amount  discount_percent  discount_amount   final_price  \
# count    203.000000        142.000000       203.000000    203.000000
# mean    1211.880094         11.725352        95.971013   1115.909081
# std     5043.227290          8.650949       605.916492   4668.315504
# min       13.964870          0.000000         0.000000     13.266626
# 25%       93.267331          5.000000         0.000000     84.876275
# 50%      198.930584         10.000000         5.380036    176.628497
# 75%      283.780764         20.000000        33.386144    262.383237
# max    44449.766867         25.000000      8300.837591  44449.766867
#
#          quantity  shipping_days  customer_rating
# count  203.000000     191.000000       176.000000
# mean     7.975369       7.338221         3.664773
# std     18.584950       3.571606         1.408589
# min     -3.000000       1.474159         1.000000
# 25%      3.000000       4.888861         2.000000
# ...

# %%
df.shape
# Out:
#   Cell In[43], line 3
#     m x n
#       ^
# SyntaxError: invalid syntax

# %%
df.columns
# Out:
# Index(['order_date', 'customer_id', 'product_category', 'order_amount',
#        'discount_percent', 'discount_amount', 'final_price', 'quantity',
#        'shipping_days', 'delivery_date', 'order_status', 'refund_status',
#        'customer_rating', 'payment_method'],
#       dtype='object')

# %%
df.dtypes
# Out:
# order_date           object
# customer_id          object
# product_category     object
# order_amount        float64
# discount_percent    float64
# discount_amount     float64
# final_price         float64
# quantity              int64
# shipping_days       float64
# delivery_date        object
# order_status         object
# refund_status        object
# customer_rating     float64
# payment_method       object
# dtype: object

# %% [markdown]
# ## selecting data

# %%
df[['customer_id','order_amount','payment_method']]
# Out:
#     customer_id  order_amount payment_method
# 0     CUST_0087     72.230845     Debit Card
# 1     CUST_0140    247.985448    Credit card
# 2     CUST_0007    242.611682    Credit card
# 3     CUST_0030   1800.303058    CREDIT CARD
# 4     CUST_0014    236.575855    CREDIT CARD
# ..          ...           ...            ...
# 198   CUST_0008    248.609202     Debit Card
# 199   CUST_0007     89.448727        Unknown
# 200   CUST_0096   1387.833108    Credit card
# 201   CUST_0025    179.693364        Unknown
# 202   CUST_0009   1107.803130         PayPal
#
# [203 rows x 3 columns]

# %%
df.iloc[0:5]
# Out:
#    order_date customer_id product_category  order_amount  discount_percent  \
# 0  2023-03-22   CUST_0087      electronics     72.230845              25.0
# 1  2023-11-09   CUST_0140      ELECTRONICS    247.985448              25.0
# 2  2024-01-20   CUST_0007           Sports    242.611682               NaN
# 3  2023-06-08   CUST_0030    Home & Garden   1800.303058               NaN
# 4  2023-03-04   CUST_0014      Electronics    236.575855               NaN
#
#    discount_amount  final_price  quantity  shipping_days delivery_date  \
# 0        18.057711    54.173134         8       3.964745    2023-03-25
# 1        61.996362   185.989086         3       4.314526           NaN
# 2         0.000000   242.611682         7       4.717731    2024-01-24
# 3         0.000000  1800.303058         9       7.652650    2023-06-15
# 4         0.000000   236.575855         2       5.659466    2023-03-09
#
#   order_status refund_status  customer_rating payment_method
# ...

# %%
df.loc[df['customer_id'] == "CUST_0009"]
# Out:
#      order_date customer_id product_category  order_amount  discount_percent  \
# 9    2023-05-31   CUST_0009         Clothing    220.575045              15.0
# 16   2023-07-10   CUST_0009            Books    189.293626              25.0
# 59   2023-03-18   CUST_0009         clothing    210.597175              25.0
# 84   2023-03-24   CUST_0009          Apparel    171.241461               0.0
# 102  2023-01-29   CUST_0009      ELECTRONICS    168.911846               NaN
# 158  2023-10-12   CUST_0009         Clothing     31.854128               NaN
# 185  2023-05-03   CUST_0009    Home & Garden    184.806746              20.0
# 187  2023-04-16   CUST_0009         clothing     48.623686              25.0
# 202  2023-05-19   CUST_0009         Clothing   1107.803130              25.0
#
#      discount_amount  final_price  quantity  shipping_days delivery_date  \
# 9          33.086257   187.488788         8      16.027394    2023-06-16
# ...

# %%
df['customer_id'].value_counts()
# Out:
# customer_id
# CUST_0009    9
# CUST_0018    9
# CUST_0019    8
# CUST_0007    8
# CUST_0008    8
#             ..
# CUST_0137    1
# CUST_0088    1
# CUST_0078    1
# CUST_0081    1
# CUST_0096    1
# Name: count, Length: 63, dtype: int64

# %%
new_data=df.drop('refund_status',axis=1)
new_data
# Out:
#      order_date customer_id product_category  order_amount  discount_percent  \
# 0    2023-03-22   CUST_0087      electronics     72.230845              25.0
# 1    2023-11-09   CUST_0140      ELECTRONICS    247.985448              25.0
# 2    2024-01-20   CUST_0007           Sports    242.611682               NaN
# 3    2023-06-08   CUST_0030    Home & Garden   1800.303058               NaN
# 4    2023-03-04   CUST_0014      Electronics    236.575855               NaN
# ..          ...         ...              ...           ...               ...
# 198  2023-06-30   CUST_0008    Home & Garden    248.609202              25.0
# 199  2023-03-22   CUST_0007      electronics     89.448727              10.0
# 200  2023-12-02   CUST_0096    Home & Garden   1387.833108              20.0
# 201  2023-03-02   CUST_0025    Home & Garden    179.693364              20.0
# 202  2023-05-19   CUST_0009         Clothing   1107.803130              25.0
#
# ...

# %%
new_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 203 entries, 0 to 202
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   order_date        203 non-null    object
#  1   customer_id       203 non-null    object
#  2   product_category  203 non-null    object
#  3   order_amount      203 non-null    float64
#  4   discount_percent  142 non-null    float64
#  5   discount_amount   203 non-null    float64
#  6   final_price       203 non-null    float64
#  7   quantity          203 non-null    int64
#  8   shipping_days     191 non-null    float64
#  9   delivery_date     152 non-null    object
#  10  order_status      203 non-null    object
#  11  customer_rating   176 non-null    float64
#  12  payment_method    203 non-null    object
# dtypes: float64(6), int64(1), object(6)
# memory usage: 20.7+ KB

# %%
df_clean=df.dropna()
df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 92 entries, 0 to 202
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   order_date        92 non-null     object
#  1   customer_id       92 non-null     object
#  2   product_category  92 non-null     object
#  3   order_amount      92 non-null     float64
#  4   discount_percent  92 non-null     float64
#  5   discount_amount   92 non-null     float64
#  6   final_price       92 non-null     float64
#  7   quantity          92 non-null     int64
#  8   shipping_days     92 non-null     float64
#  9   delivery_date     92 non-null     object
#  10  order_status      92 non-null     object
#  11  refund_status     92 non-null     object
#  12  customer_rating   92 non-null     float64
#  13  payment_method    92 non-null     object
# dtypes: float64(6), int64(1), object(7)
# memory usage: 10.8+ KB
